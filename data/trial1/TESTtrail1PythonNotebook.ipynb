# %%
import pandas as pd
import pylab
from pylab import *

# %%
ls
# Out:
# 0215-4.csv  testCol

# %%
annotated = read_csv('testCol')
annotated.ix[0:, ['sender', 'contents', 'tangram']]
director = annotated[annotated['sender'] == 'director'] 
# director
annotated['tangram'] != 0
tangramA = annotated[annotated['tangram'] != '0']
tangramA.ix[0:, ['roundNum', 'contents', 'tangram']]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-175-c0eb043a25de> in <module>()
# ----> 1 annotated = read_csv('testCol')
#       2 annotated.ix[0:, ['sender', 'contents', 'tangram']]
#       3 # director = annotated[annotated['sender'] == 'director']
#       4 # director
#       5 # annotated['tangram'] != 0
#
# /users/nickimaslan/Downloads/Applications/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     472                     skip_blank_lines=skip_blank_lines)
#     473
# --> 474         return _read(filepath_or_buffer, kwds)
#     475
#     476     parser_f.__name__ = name
#
# /users/nickimaslan/Downloads/Applications/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     248
#     249     # Create the parser.
# --> 250     parser = TextFileReader(filepath_or_buffer, **kwds)
#     251
#     252     if (nrows is not None) and (chunksize is not None):
#
# /users/nickimaslan/Downloads/Applications/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     564             self.options['has_index_names'] = kwds['has_index_names']
#     565
# --> 566         self._make_engine(self.engine)
#     567
#     568     def _get_options_with_defaults(self, engine):
#
# /users/nickimaslan/Downloads/Applications/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     703     def _make_engine(self, engine='c'):
#     704         if engine == 'c':
# --> 705             self._engine = CParserWrapper(self.f, **self.options)
#     706         else:
#     707             if engine == 'python':
#
# /users/nickimaslan/Downloads/Applications/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1070         kwds['allow_leading_cols'] = self.index_col is not False
#    1071
# -> 1072         self._reader = _parser.TextReader(src, **kwds)
#    1073
#    1074         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3173)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5912)()
#
# IOError: File testCol does not exist

# %%
ls
# Out:
# 0215-4.csv  testCol     testRound1

# %%
muffins = read_csv('merged.csv')
muffins
muffins.ix[0:, ['gameid', 'roundNum', 'sender', 'contents', 'tangram']]
director = muffins[muffins['sender'] == 'director']
tangramA = muffins[muffins['tangram'] == 'E']
# tangramARound1 = tangramA[tangramA['roundNum'] == '1']
# tangramA.set_index(['roundNum'])
sorteddata = tangramA.sort(['roundNum'])
# sorteddataRound1 = sorteddata[sorteddata['roundNum'] == '2']
# sorteddataRound1 = sorteddata.sort(['gameid'])
sorteddataRound1 = sorteddata[sorteddata['gameid'] != '0']
# sorteddata
sorteddataRound1
# Out:
#       gameid           time roundNum    sender  \
# 1274  3423-d  1438805962421        1   matcher
# 687   2388-c  1438808898380        1   matcher
# 686   2388-c  1438808889906        1  director
# 685   2388-c  1438808867276        1   matcher
# 585   2121-8  1438802548757        1  director
# 1272  3423-d  1438805934054        1  director
# 1249  3423-d  1438805403971        1   matcher
# 1248  3423-d  1438805353736        1  director
# 1029  3409-e  1438803837184        1  director
# 1001  3409-e  1438802884106        1  director
# 166   0619-a  1438802809657        1  director
# 167   0619-a  1438802828348        1   matcher
# 26    0215-4  1438804568938        1  director
# 1275  3423-d  1438805968319        1  director
# 866   2878-d  1438802806648        1   matcher
# 845   2878-d  1438802440677        1  director
# 844   2878-d  1438802436818        1   matcher
# 843   2878-d  1438802429957        1   matcher
# 25    0215-4  1438804538715        1   matcher
# 701   2388-c  1438809236425        1  director
# 700   2388-c  1438809232058        1   matcher
# 406   1903-d  1438804346910        1  director
# 407   1903-d  1438804354535        1   matcher
# 408   1903-d  1438804357535        1  director
# 409   1903-d  1438804361315        1   matcher
# 455   1903-d  1438805090917        1   matcher
# 456   1903-d  1438805092740        1   matcher
# 457   1903-d  1438805096457        1  director
# 458   1903-d  1438805102742        1  director
# 1273  3423-d  1438805953273        1   matcher
# ...      ...            ...      ...       ...
# 1398  3423-d  1438808350017        4  director
# 1163  3409-e  1438806441706        4   matcher
# 1164  3409-e  1438806445411        4  director
# 102   0215-4  1438805724006        4  director
# 541   1903-d  1438805638641        4  director
# 647   2121-8  1438803604514        4  director
# 537   1903-d  1438805618472        4  director
# 112   0215-4  1438805857421        5   matcher
# 544   1903-d  1438805660408        5  director
# 337   0619-a  1438805200582        5  director
# 1419  3423-d  1438808566089        5  director
# 803   2388-c  1438810088974        5  director
# 1170  3409-e  1438806499667        5   matcher
# 1172  3409-e  1438806508779        5  director
# 951   2878-d  1438803887982        5   matcher
# 952   2878-d  1438803892705        5  director
# 340   0619-a  1438805211332        5   matcher
# 113   0215-4  1438805876768        5  director
# 662   2121-8  1438803742460        5  director
# 974   2878-d  1438804090334        6  director
# 146   0215-4  1438806166565        6   matcher
# 1430  3423-d  1438808659935        6  director
# 387   0619-a  1438805578396        6  director
# 388   0619-a  1438805585956        6   matcher
# 1200  3409-e  1438806791453        6   matcher
# 818   2388-c  1438810130418        6  director
# 569   1903-d  1438805775509        6  director
# 674   2121-8  1438803850808        6  director
# 973   2878-d  1438804082312        6   matcher
# 147   0215-4  1438806172469        6  director
#
#                                                contents tangram
# 1274                            has a bow or bunny ears       E
# 687                                              got it       E
# 686                                      that is spot 7       E
# 685   which spot has the one that looks like a bunny...       E
# 585         5 and indian sitting with a headress thingy       E
# 1272  Ok, 6 kind of looks like 11 (sad person) but t...       E
# 1249                                       got that one       E
# 1248  11 looks like a sad person sitting down on a b...       E
# 1029    12 is sitting facing right, but also bunny ears       E
# 1001                                  12 has bunny ears       E
# 166   The one that looks like a rabbit sitting (faci...       E
# 167                                              got it       E
# 26    11: his head is a block, facing right side, si...       E
# 1275                                                yes       E
# 866                                      8.  bunny ears       E
# 845                                                   8       E
# 844                   two distinct triangles at the top       E
# 843   there is one that sort of has bunny ears, wher...       E
# 25                                                ok 11       E
# 701                                                 yep       E
# 700                               7 is the bunny right?       E
# 406                      1. kind of looks like a rabbit       E
# 407                                facing to the right?       E
# 408                                                 yup       E
# 409                                           ok got it       E
# 455   ok and there's one that looks like a rabbit lo...       E
# 456                                         facing left       E
# 457                                                   1       E
# 458                                                wait       E
# 1273                                            got it        E
# ...                                                 ...     ...
# 1398                                     10 rabbit ears       E
# 1163                                        Bunny ears?       E
# 1164                                                  9       E
# 102   8: sitting against a wall, facing right side b...       E
# 541                                 11. lounging rabbit       E
# 647                                            8 indian       E
# 537               7. rabbit facing right / looking down       E
# 112                                               and 2       E
# 544                      1. rabbit looking right / down       E
# 337                                          Rabbit - 1       E
# 1419                                    12 rabbit ears.       E
# 803                                               bunny       E
# 1170                                        Bunny ears?       E
# 1172                                           12 and 6       E
# 951                                               bunny       E
# 952                                                   6       E
# 340                                                   k       E
# 113                2: two triangles resting on his head       E
# 662                                            8 indian       E
# 974                                                   3       E
# 146                                                ok 7       E
# 1430                                  8 is rabbit ears.       E
# 387                                           5- rabbit       E
# 388                                                   k       E
# 1200                                        bunny ears?       E
# 818                                               bunny       E
# 569               12 rabbit facing right / looking down       E
# 674                                            8 indian       E
# 973                                               bunny       E
# 147                    7: two triangles resting on head       E
#
# [97 rows x 6 columns]

# %%
penguins = read_csv('3682-d.csv')
penguins
# Out:
#      gameid           time  roundNum    sender  \
# 0    3682-d  1438802839764         1  director
# 1    3682-d  1438802842355         1   matcher
# 2    3682-d  1438802851200         1   matcher
# 3    3682-d  1438802872587         1   matcher
# 4    3682-d  1438802881442         1  director
# 5    3682-d  1438802887537         1   matcher
# 6    3682-d  1438802900585         1   matcher
# 7    3682-d  1438802911017         1  director
# 8    3682-d  1438802934585         1   matcher
# 9    3682-d  1438802942205         1  director
# 10   3682-d  1438802953480         1   matcher
# 11   3682-d  1438802988272         1  director
# 12   3682-d  1438803000072         1  director
# 13   3682-d  1438803007930         1   matcher
# 14   3682-d  1438803046942         1  director
# 15   3682-d  1438803059121         1   matcher
# 16   3682-d  1438803063399         1  director
# 17   3682-d  1438803074486         1   matcher
# 18   3682-d  1438803097241         1   matcher
# 19   3682-d  1438803115486         1  director
# 20   3682-d  1438803145553         1   matcher
# 21   3682-d  1438803172491         1  director
# 22   3682-d  1438803197056         1   matcher
# 23   3682-d  1438803220318         1  director
# 24   3682-d  1438803230522         1   matcher
# 25   3682-d  1438803256619         1  director
# 26   3682-d  1438803262208         1  director
# 27   3682-d  1438803268020         1   matcher
# 28   3682-d  1438803283091         1  director
# 29   3682-d  1438803296236         1   matcher
# ..      ...            ...       ...       ...
# 129  3682-d  1438804512997         5  director
# 130  3682-d  1438804512997         5  director
# 131  3682-d  1438804512997         5  director
# 132  3682-d  1438804545026         5  director
# 133  3682-d  1438804545026         5  director
# 134  3682-d  1438804545026         5  director
# 135  3682-d  1438804607045         5   matcher
# 136  3682-d  1438804614186         6  director
# 137  3682-d  1438804619321         6   matcher
# 138  3682-d  1438804629860         6   matcher
# 139  3682-d  1438804656042         6  director
# 140  3682-d  1438804656042         6  director
# 141  3682-d  1438804656042         6  director
# 142  3682-d  1438804656042         6  director
# 143  3682-d  1438804656042         6  director
# 144  3682-d  1438804679515         6   matcher
# 145  3682-d  1438804699921         6  director
# 146  3682-d  1438804699921         6  director
# 147  3682-d  1438804699921         6  director
# 148  3682-d  1438804719219         6   matcher
# 149  3682-d  1438804730817         6  director
# 150  3682-d  1438804730817         6  director
# 151  3682-d  1438804730817         6  director
# 152  3682-d  1438804730817         6  director
# 153  3682-d  1438804750926         6  director
# 154  3682-d  1438804750926         6  director
# 155  3682-d  1438804750926         6  director
# 156  3682-d  1438804750926         6  director
# 157  3682-d  1438804751568         6   matcher
# 158  3682-d  1438804761725         6   matcher
#
#                                               contents tangram
# 0                                                   hi       0
# 1                                                   hi       0
# 2                             i'm kind of confused lol       0
# 3          i know i have to match your board but how?!       0
# 4              I have to tell you which one goes where       0
# 5                                            ohhhh ok!       0
# 6                          k, so i guess I'm ready :-)       0
# 7    the one that's sitting/laying down with the le...       F
# 8                                                    k       F
# 9      the one that looks like it has bunny ears is 11       E
# 10                                                   k       E
# 11   the one that looks like a backwards L, with tw...       G
# 12                    a backwards L with a square head       G
# 13                                                   k       G
# 14                                                  hm       0
# 15                                                   ?       0
# 16   a diamond head with the left side completely f...       J
# 17   just so you know if i say k, that means I'm do...       0
# 18                                                   k       J
# 19   a square head that looks like it's being poked...       B
# 20                                                   k       B
# 21   a person that looks like it is starting to run...       A
# 22                                                   k       A
# 23   a person that looks like it has its hands rais...       C
# 24                                                   k       C
# 25   a person with a diamond head, right side compl...       D
# 26                                                is 5       D
# 27                                                   k       D
# 28   a person that looks like it has a tail, or kic...       I
# 29                                                   k       I
# ..                                                 ...     ...
# 129                     two arms raised leaning left 8       C
# 130                            the not > kneeling at 9       K
# 131                                        the > at 10       L
# 132  flat leftside, foot/arm right 11, hexagonal bo...       0
# 133                   flat leftside, foot/arm right 11       J
# 134     hexagonal body with a triangle bottom right 12       H
# 135                                                  k       0
# 136                                                O.o       0
# 137                                     9?!!?  yeah ok       0
# 138                                 this is ridiculous       0
# 139  bunny ears 1, two arms raised leaning left 2, ...       0
# 140                                       bunny ears 1       E
# 141                     two arms raised leaning left 2       C
# 142      foot to the left with the tail or ballerina 3       I
# 143                                     running pose 4       A
# 144                                                  k       0
# 145             the not > kneeling 5, the > kneeling 6       0
# 146                               the not > kneeling 5       K
# 147                                   the > kneeling 6       L
# 148                                                  k       0
# 149  flat rightside 7, flat leftside 8, stabbed in ...       0
# 150                                   flat rightside 7       D
# 151                                    flat leftside 8       J
# 152              stabbed in the neck with a triangle 9       B
# 153  hexagonal body with bottom right triangle 10, ...       0
# 154       hexagonal body with bottom right triangle 10      10
# 155                                    slumped body 11       F
# 156                                     backwards L 12       G
# 157                                                  k       0
# 158                                                  k       0
#
# [159 rows x 6 columns]
