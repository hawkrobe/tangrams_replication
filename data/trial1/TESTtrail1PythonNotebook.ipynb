# %%
import pandas as pd
import pylab
from pylab import *

# %%
ls
# Out:
# 0215-4.csv  testCol

# %%
annotated = read_csv('testCol')
annotated.ix[0:, ['sender', 'contents', 'tangram']]
director = annotated[annotated['sender'] == 'director'] 
# director
annotated['tangram'] != 0
tangramA = annotated[annotated['tangram'] != '0']
tangramA.ix[0:, ['roundNum', 'contents', 'tangram']]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-220-5bbaa90f7e07> in <module>()
# ----> 1 annotated = read_csv('testCol')
#       2 annotated.ix[0:, ['sender', 'contents', 'tangram']]
#       3 director = annotated[annotated['sender'] == 'director']
#       4 # director
#       5 annotated['tangram'] != 0
#
# ...

# %%
ls
# Out:
# 0215-4.csv  testCol     testRound1

# %%
muffins = read_csv('merged.csv')
muffins
muffins.ix[0:, ['gameid', 'roundNum', 'sender', 'contents', 'tangram']]
director = muffins[muffins['sender'] == 'director']
tangramA = muffins[muffins['tangram'] == 'F']
# tangramARound1 = tangramA[tangramA['roundNum'] == '1']
# tangramA.set_index(['roundNum'])
sorteddata = tangramA.sort(['roundNum'])
# sorteddataRound1 = sorteddata[sorteddata['roundNum'] == '2']
# sorteddataRound1 = sorteddata.sort(['gameid'])
sorteddataRound1 = sorteddata[sorteddata['roundNum'] == '6']
sorteddataRound1
# directorSort = sorteddataRound1[sorteddataRound1['sender'] == 'director']
# directorSort
# Out:
#       gameid           time roundNum    sender  \
# 2023  4060-2  1438807646504        6   matcher
# 966   2878-d  1438804048635        6  director
# 382   0619-a  1438805535718        6  director
# 1424  3423-d  1438808616606        6  director
# 1791  3891-4  1438805543649        6   matcher
# 2333  4800-3  1438804464708        6  director
# 2487  6510-9  1438805022844        6  director
# 142   0215-4  1438806144578        6   matcher
# 667   2121-8  1438803796514        6  director
# 965   2878-d  1438804045337        6   matcher
# 2574  7764-f  1438808949193        6  director
# 2489  6510-9  1438805032209        6   matcher
# 1207  3409-e  1438806874172        6   matcher
# 1209  3409-e  1438806882607        6  director
# 2182  4404-5  1438805729194        6  director
# 564   1903-d  1438805749941        6  director
# 143   0215-4  1438806154717        6  director
# 820   2388-c  1438810130418        6  director
# 1792  3891-4  1438805550796        6  director
# ...

# %%
penguins = read_csv('round2_4927-0.csv')
penguins
# Out:
#      gameid           time  roundNum    sender  \
# 0    4927-0  1438964304723         1  director
# 1    4927-0  1438964314352         1   matcher
# 2    4927-0  1438964352279         1   matcher
# 3    4927-0  1438964367618         1  director
# 4    4927-0  1438964375954         1  director
# 5    4927-0  1438964388218         1  director
# 6    4927-0  1438964396993         1   matcher
# 7    4927-0  1438964408783         1   matcher
# 8    4927-0  1438964409346         1  director
# 9    4927-0  1438964441051         1  director
# 10   4927-0  1438964463929         1   matcher
# 11   4927-0  1438964472728         1   matcher
# 12   4927-0  1438964483322         1  director
# 13   4927-0  1438964494082         1  director
# 14   4927-0  1438964507668         1   matcher
# 15   4927-0  1438964533650         1  director
# 16   4927-0  1438964550586         1  director
# 17   4927-0  1438964576024         1   matcher
# 18   4927-0  1438964612609         1  director
# ...
